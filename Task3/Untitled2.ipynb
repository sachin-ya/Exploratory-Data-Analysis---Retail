# %% [markdown]
# <h4>Name: Sachin Yadav </h4>
# <h4>Status: Intern </h4>
# <h4>Organization: The Sparks Foundation</h4>
# <h4>Task3:‘Exploratory Data Analysis’ on dataset ‘SampleSuperstore’.As a business manager, try to find out the weak areas where you can work to make more profit. What all business problems you can derive by exploring the data? </h4>

# %% [markdown]
# <h4>Step1:Import Libraries & Dataset</h4>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('SampleSuperstore.csv') # Reading the Dataset

# %%
df.head(5)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.tail(5)
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.isna().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.nunique() #display the unique data
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# <h4>Step 2: Checking for the duplicate data. if yes , then dropping those data.</h4>

# %%
df.duplicated().sum() #checks the duplicated data
# Out:
# 17

# %%
df.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.nunique() #display the unique data
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# <h4>Step3: Checking Statistical relation between the various rows & columns</h4>

# %%
df.corr() # corrrelation between variables
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
df.cov() #covariance of columns
# Out:
#               Postal Code          Sales    Quantity    Discount  \
# Postal Code  1.028080e+09 -476682.766590  910.415885  386.870404
# Sales       -4.766828e+05  388434.455308  278.459923   -3.627228
# Quantity     9.104159e+02     278.459923    4.951113    0.003961
# Discount     3.868704e+02      -3.627228    0.003961    0.042622
# Profit      -2.250458e+05   69944.096586   34.534769  -10.615173
#
#                     Profit
# Postal Code -225045.849445
# Sales         69944.096586
# Quantity         34.534769
# Discount        -10.615173
# Profit        54877.798055

# %% [markdown]
# <h4>Step4: Data visualization</h4>

# %%
#we can also see ,is there any null value or not with help of heatmap
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
#Bar graph between Sub-Category Vs Category
plt.figure(figsize=(16,10))
plt.bar('Sub-Category', 'Category',data=df)
plt.title('Sub-Category Vs Category')
plt.xlabel('Sub-Category')
plt.ylabel('Category')
plt.xticks(rotation=45)
plt.show()

# %%
df.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(df['Sales'], color='red', label='Sales', shade=True,bw_method=25)
sns.kdeplot(df['Profit'], color='Blue', label='Profit', shade=True,bw_method=25)
plt.legend()

# %% [markdown]
# <h4>Analysis using pairplot of each column</h4>
# <h4>[1] Based on the Category </h4>

# %%
sns.pairplot(df,hue='Category')

# %% [markdown]
# <h4>[2] Based on Region </h4>

# %%
sns.pairplot(df,hue='Region')

# %% [markdown]
# <h4>[3] Based on Segment </h4>

# %%
sns.pairplot(df,hue='Segment')

# %%
df.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %% [markdown]
# <h4>HeatMap for Correlation </h4>

# %%
sns.heatmap(df.corr(), cmap='rocket_r', annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h4> Count plot of each column </h4>

# %%
fig,axs=plt.subplots(nrows=2, ncols=2,figsize=(10,7))
sns.countplot(df['Category'],ax=axs[0][0])
sns.countplot(df['Segment'],ax=axs[0][1])
sns.countplot(df['Ship Mode'],ax=axs[1][0])
sns.countplot(df['Region'],ax=axs[1][1])
axs[0][0].set_title('Category', fontsize=20)
axs[0][1].set_title('Segment', fontsize=20)
axs[1][0].set_title('Ship Mode', fontsize=20)
axs[1][1].set_title('Region', fontsize=20)
plt.tight_layout()

# %%
plt.figure(figsize=(20,8))
sns.countplot(df['Sub-Category'])
plt.title('Sub-Category', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Sub-Category')

# %%
#count the total repeatable states
df['State'].value_counts()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Mississippi               53
# Utah                      53
# ...

# %%
plt.figure(figsize=(15,15))
sns.countplot(x=df['State'])
plt.xticks(rotation=90)
plt.title('STATE')
plt.show()

# %%
plt.figure(figsize=(18,5))
sns.countplot(df['Quantity'])
plt.title('Quantity',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Quantity')

# %%
plt.figure(figsize=(18,5))
sns.countplot(df['Discount'])
plt.xticks(rotation=90)
plt.title('Discount', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Discount')

# %% [markdown]
# <h4>Distribution of the data using the plot</h4>

# %%
fig,axs=plt.subplots(nrows=2, ncols=2,figsize=(10,10))
sns.distplot(df['Sales'],ax=axs[0][0])
sns.distplot(df['Profit'],ax=axs[0][1])
sns.distplot(df['Quantity'],ax=axs[1][0])
sns.distplot(df['Discount'],ax=axs[1][1])
axs[0][0].set_title('Sales', fontsize=20)
axs[0][1].set_title('Profit', fontsize=20)
axs[1][0].set_title('Quantity', fontsize=20)
axs[1][1].set_title('Discount', fontsize=20)
plt.show()

# %% [markdown]
# <h4>Statewise Deal Analysis</h4>

# %%
df['Country'].value_counts()
# Out:
# United States    9994
# Name: Country, dtype: int64

# %%
df1=df['State'].value_counts()
df1.head(10)
# Out:
# California        2001
# New York          1128
# Texas              985
# Pennsylvania       587
# Washington         506
# Illinois           492
# Ohio               469
# Florida            383
# Michigan           255
# North Carolina     249
# Name: State, dtype: int64

# %%
df1.plot(kind='bar', figsize=(15,5))
plt.ylabel('Freuency/Number of deals')
plt.xlabel('States')

plt.title('State wise Dealing', fontsize=20)
plt.show()

# %% [markdown]
# <h4>Here is top 3 state where deals are highest </h4>
# <h4>1.California</h4>
# <h4>2.New York</h4>
# <h4>3.Texas</h4>
# <h4>Wyoming: Lowest Number of deal</h4>

# %%
df['State'].value_counts().mean()
# Out:
# 203.9591836734694

# %% [markdown]
# <h4>Average number of deal per state is 204</h4>

# %% [markdown]
# <h4>City Wise analysis of the dealing</h4>

# %%
df2=df['City'].value_counts()
df2=df2.head(50)

# %%
df2.plot(kind='bar', figsize=(15,5))
plt.ylabel('Frequency/Number of deals')
plt.xlabel('City')
plt.title('City wise Dealing', fontsize=20)
plt.show()

# %% [markdown]
# <h4> Here is top 3 city where deals are highest</h4>
# <h4>1.New York City</h4>
# <h4>2.Los Angeles</h4>
# <h4>3.Philadelphia</h4>

# %%
df['City'].value_counts().mean()
# Out:
# 18.821092278719398

# %% [markdown]
# <h4>Average number of deal per city is 19</h4>

# %% [markdown]
# <h4>Segment wise analysis of Profit, Discount and sale</h4>

# %%
df['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
df_segment=df.groupby(['Segment'])[['Sales','Discount','Profit']].mean()
df_segment
# Out:
#                   Sales  Discount     Profit
# Segment
# Consumer     223.733644  0.158141  25.836873
# Corporate    233.823300  0.158228  30.456667
# Home Office  240.972041  0.147128  33.818664

# %%
#1.sales 2.Discount 3.Profit
df_segment.plot.pie(subplots=True,
                    autopct='%1.1f%%',
                    figsize=(18,20),
                    startangle=90,
                    shadow=True,
                    labels=df_segment.index)
plt.title('Segment wise analysis of sale, Discount, Profit')
# Out:
# Text(0.5, 1.0, 'Segment wise analysis of sale, Discount, Profit')

# %% [markdown]
# <h4>Statewise analysis of profit , discount and sale</h4>

# %%
df['State'].value_counts().head(10)
# Out:
# California        2001
# New York          1128
# Texas              985
# Pennsylvania       587
# Washington         506
# Illinois           492
# Ohio               469
# Florida            383
# Michigan           255
# North Carolina     249
# Name: State, dtype: int64

# %%
df_state=df.groupby(['State'])[['Sales','Discount','Profit']].mean()
df_state.head(10)
# Out:
#                            Sales  Discount      Profit
# State
# Alabama               319.846557  0.000000   94.865989
# Arizona               157.508933  0.303571  -15.303235
# Arkansas              194.635500  0.000000   66.811452
# California            228.729451  0.072764   38.171608
# Colorado              176.418231  0.316484  -35.867351
# Connecticut           163.223866  0.007317   42.823071
# Delaware              285.948635  0.006250  103.930988
# District of Columbia  286.502000  0.000000  105.958930
# Florida               233.612815  0.299347   -8.875461
# Georgia               266.825217  0.000000   88.315453

# %% [markdown]
# <h4>[1] Statewise Profit Analysis</h4>

# %%
df_state1=df_state.sort_values('Profit')

df_state1[['Profit']].plot(kind='bar', figsize=(15,4))
plt.title('State wise profit analysis', fontsize=20)
plt.ylabel('profit per state')
plt.xlabel('States')
plt.show()

# %% [markdown]
# <h4>Statewise sale Analysis</h4>

# %%
df_state['Sales'].plot(kind='pie',
                      figsize=(20,20),
                      autopct='%1.1f%%',
                      startangle=90,
                      shadow=True)
plt.title('State wise analysis of Sale',fontsize=20)
# Out:
# Text(0.5, 1.0, 'State wise analysis of Sale')

# %% [markdown]
# <h4>highes amount of sales= yoming(11.8%)</h4>
# <h4>Lowest amount of sales=South Dakota(0.8%)</h4>

# %% [markdown]
# <h4>[3] StateWise Discount Analysis</h4>

# %%
df_state1['Discount'].plot(kind='bar', figsize=(18,5))
plt.title('State wise analysis of Discount', fontsize=20)
# Out:
# Text(0.5, 1.0, 'State wise analysis of Discount')

# %% [markdown]
# <h5>lllinois at the top</h5>

# %% [markdown]
# <h4>citywise analysis of the profit</h4>

# %%
df_city=df.groupby(['City'])[['Sales', 'Discount', 'Profit']].mean()
df_city=df_city.sort_values('Profit')
df_city.head()
# Out:
#                  Sales  Discount      Profit
# City
# Bethlehem   337.926800  0.380000 -200.619160
# Champaign   151.960000  0.600000 -182.352000
# Oswego      107.326000  0.600000 -178.709200
# Round Rock  693.436114  0.274286 -169.061614
# Lancaster   215.031826  0.315217 -157.371052

# %%
#1.low profit
df_city['Profit'].head(30).plot(kind='bar', figsize=(15,5), color='Green')
plt.title('city wise analysis of sale, discount, profit')
# Out:
# Text(0.5, 1.0, 'city wise analysis of sale, discount, profit')

# %%
#high profit
df_city['Profit'].tail(30).plot(kind='bar', figsize=(15,5), color='Violet')
plt.title('city wise analysis of sale, discount, profit')
# Out:
# Text(0.5, 1.0, 'city wise analysis of sale, discount, profit')

# %%
# 30 cities which has profit in positive
## 30 cities which has profit in negative
# the balance is pretty good here

# %% [markdown]
# <h4>QUANTITY WISE SALES, PROFIT AND DISCOUNT ANALYSIS</h4>

# %%
df_quantity=df.groupby(['Quantity'])[['Sales','Discount','Profit']].mean()
df_quantity.head(10)
# Out:
#                Sales  Discount     Profit
# Quantity
# 1          59.234632  0.152959   8.276396
# 2         120.354488  0.154858  16.006831
# 3         175.201578  0.153329  23.667715
# 4         271.764059  0.157708  37.131310
# 5         337.936339  0.157146  40.257394
# 6         362.101960  0.166556  18.051517
# 7         395.888393  0.161980  56.579163
# 8         458.210802  0.171595  42.244342
# 9         498.083683  0.147946  68.557716
# 10        422.046737  0.190702  35.862404

# %%
#1. sales 2. Discount 3.Profit
df_quantity.plot.pie(subplots=True,
                    autopct='%1.1f%%',
                     figsize=(25,25),
                    pctdistance=0.69,
                    startangle=90,
                    shadow=True,
                    labels=df_quantity.index)
plt.title('Quantity wise analysis of sale, discount, profit')
# Out:
# Text(0.5, 1.0, 'Quantity wise analysis of sale, discount, profit')

# %%
# 13 number of quantity is high for sales and profit

# %% [markdown]
# <h4>CATEGORY WISE SALES, DISCOUNT AND PROFIT</h4>

# %%
df_category =df.groupby(['Category'])[['Sales','Discount','Profit']].mean()
df_category
# Out:
#                       Sales  Discount     Profit
# Category
# Furniture        349.834887  0.173923   8.699327
# Office Supplies  119.324101  0.157285  20.327050
# Technology       452.709276  0.132323  78.752002

# %%
df_category.plot.pie(subplots=True,
                    figsize=(18,20),
                    autopct='%1.1f%%',
                    labels=df_category.index)
# Out:
# array([<AxesSubplot:ylabel='Sales'>, <AxesSubplot:ylabel='Discount'>,
#        <AxesSubplot:ylabel='Profit'>], dtype=object)

# %%
#maximum sales and profit obtain in technology
#minimum profit obtain in furniture

# %% [markdown]
# <h4>Sub-Category wise Sales, Profit and Discount</h4>

# %%
df_sub_category=df.groupby(['Sub-Category'])[['Sales','Discount','Profit']].mean()
df_sub_category.head(10)
# Out:
#                     Sales  Discount      Profit
# Sub-Category
# Accessories    215.974604  0.078452   54.111788
# Appliances     230.755710  0.166524   38.922758
# Art             34.068834  0.074874    8.200737
# Binders        133.560560  0.372292   19.843574
# Bookcases      503.859633  0.211140  -15.230509
# Chairs         532.332420  0.170178   43.095894
# Copiers       2198.941618  0.161765  817.909190
# Envelopes       64.867724  0.080315   27.418019
# Fasteners       13.936774  0.082028    4.375660
# Furnishings     95.825668  0.138349   13.645918

# %% [markdown]
# <h4>[1]  BASED ON THE SALES</h4>

# %%
plt.figure(figsize=(15,15))
plt.pie(df_sub_category['Sales'],labels=df_sub_category.index, autopct='%1.1f%%')
plt.title('Sub-Category wise sales analysis',fontsize=20)
plt.legend()
plt.xticks(rotation=90)
plt.show()

# %%
#copier and machine have high sales

# %% [markdown]
# <h4>[2]BASED ON THE DISCOUNT</h4>

# %%
plt.figure(figsize=(15,15))
plt.pie(df_sub_category['Discount'],labels=df_sub_category.index, autopct='%1.1f%%')
plt.title('Sub-Category wise Discount analysis',fontsize=20)
plt.legend()
plt.xticks(rotation=90)
plt.show()

# %%
#binders, machine and then tables have high Discount

# %% [markdown]
# <h4>[3] BASED ON THE PROFIT</h4>

# %%
df_sub_category.sort_values('Profit')[['Sales','Profit']].plot(kind='bar', figsize=(10,5), label=['Avg Sales Price($)','Profit($)'])
# Out:
# <AxesSubplot:xlabel='Sub-Category'>

# %%
#copier:highest profit as well as sale

# %% [markdown]
# <h4>REGION WISE ANALYSIS </h4>

# %%
df_region=df.groupby(['Region'])[['Sales','Discount','Profit']].mean()
df_region
# Out:
#               Sales  Discount     Profit
# Region
# Central  215.772661  0.240353  17.092709
# East     238.336110  0.145365  32.135808
# South    241.803645  0.147253  28.857673
# West     226.493233  0.109335  33.849032

# %%
df_region.plot.pie(subplots=True,figsize=(18,20),autopct='%1.1f%%',labels=df_region.index)
# Out:
# array([<AxesSubplot:ylabel='Sales'>, <AxesSubplot:ylabel='Discount'>,
#        <AxesSubplot:ylabel='Profit'>], dtype=object)

# %%
#west: have highest profit

# %% [markdown]
# <h4>SHIP MODE WISE ANALYSIS </h4>

# %%
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
df_shipmode=df.groupby(['Ship Mode'])[['Sales','Discount','Profit']].mean()

# %%
df_shipmode.plot.pie(subplots=True,
                    figsize=(18,20),
                    autopct='%1.1f%%',
                    labels=df_shipmode.index)
# Out:
# array([<AxesSubplot:ylabel='Sales'>, <AxesSubplot:ylabel='Discount'>,
#        <AxesSubplot:ylabel='Profit'>], dtype=object)

# %%
#profit and discount is high in first class
#sales is high for same day ship

# %% [markdown]
# <h4>RESULT AND CONCLUSION</h4>

# %%
#1.Profit  is more than that of  sale but  there are some areas where profit could be increased
#2.Profit and Discount is high in First class
#3.Sales is high for Same day ship
#4.sub-category : Copier: high profit & sales
#5.sub-category: binder, machines and then tables have high discount
#6.state:Vemont:highest profit
#7.sate:ohio:Lowest Profit
#8.Segment:Home-office high profit & sales
#9.here is top 3 city where deals are highest
   #a.California
   #b.New York
   #c.Texas
#whyoming:lowest number of deal,highest amount of sales=wyoming(11.8%)
#lowest amount of sales=south Dakota(0.8%)

# %% [markdown]
# <h1>THANK YOU</h1>
